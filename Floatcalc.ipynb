# %%
import pandas as pd
df = pd.read_csv('/Users/aj/Documents/Texas State Docs/Fall 2025/Machine Learning/Project/ML-Project/Retrieval/Data_Combined/dota_pro_combined.csv')
float_columns = df.select_dtypes(include=['float64', 'float32']).columns
num_float_columns = len(float_columns)
print(f"Number of columns with float data types: {num_float_columns}")
print(f"Float columns: {list(float_columns)}")
total_float_values = 0
for column in df.columns:
    total_float_values += df[column].apply(lambda x: isinstance(x, (float))).sum()
print(f"Total number of individual float values in the dataset: {total_float_values}")

num_entries = len(df)
print(f"Total number of entries (rows) in the dataset: {num_entries}")
# Out:
# Number of columns with float data types: 50
# Float columns: ['region', 'skill', 'kills_dire', 'kills_radiant', 'deaths_dire', 'deaths_radiant', 'assists_dire', 'assists_radiant', 'last_hits_dire', 'last_hits_radiant', 'denies_dire', 'denies_radiant', 'gold_per_min_dire', 'gold_per_min_radiant', 'xp_per_min_dire', 'xp_per_min_radiant', 'gold_spent_dire', 'gold_spent_radiant', 'hero_damage_dire', 'hero_damage_radiant', 'hero_healing_dire', 'hero_healing_radiant', 'tower_damage_dire', 'tower_damage_radiant', 'level_dire', 'level_radiant', 'obs_placed_dire', 'obs_placed_radiant', 'sen_placed_dire', 'sen_placed_radiant', 'roshans_killed_dire', 'roshans_killed_radiant', 'towers_killed_dire', 'towers_killed_radiant', 'objective_type_CHAT_MESSAGE_AEGIS', 'objective_type_CHAT_MESSAGE_AEGIS_STOLEN', 'objective_type_CHAT_MESSAGE_COURIER_LOST', 'objective_type_CHAT_MESSAGE_DENIED_AEGIS', 'objective_type_CHAT_MESSAGE_FIRSTBLOOD', 'objective_type_CHAT_MESSAGE_MINIBOSS_KILL', 'objective_type_CHAT_MESSAGE_ROSHAN_KILL', 'objective_type_building_kill', 'final_gold_advantage', 'final_xp_advantage', 'event_buyback_count', 'event_kill_count', 'event_purchase_count', 'event_rune_count', 'observer_wards_placed', 'sentry_wards_placed']
# Total number of individual float values in the dataset: 750000
# Total number of entries (rows) in the dataset: 15000
